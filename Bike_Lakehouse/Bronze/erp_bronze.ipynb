# %% [markdown]
# #Reading From CSV File

# %% [markdown]
# #load "CUST_AZ12.csv

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv('/Volumes/workspace_1/bronze/source_systems/source_erp/CUST_AZ12.csv', header=True)
df.write.mode("overwrite").saveAsTable("workspace_1.bronze.erp_cust_az12")

# %% [markdown]
# # load LOC_A101.csv

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv('/Volumes/workspace_1/bronze/source_systems/source_erp/LOC_A101.csv', header=True)
df.write.mode("overwrite").saveAsTable("workspace_1.bronze.erp_loc_a101")

# %% [markdown]
# # load PX_CAT_G1V2.csv

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv('/Volumes/workspace_1/bronze/source_systems/source_erp/PX_CAT_G1V2.csv', header=True)
df.write.mode("overwrite").saveAsTable("workspace_1.bronze.erp_px_cat_g1v2")
